# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Reading the data**

# %%
df = pd.read_csv('data/first_data.txt',header=None,names=['City Population','Average Profit'])
df
# Out:
#     City Population  Average Profit
# 0            6.1101        17.59200
# 1            5.5277         9.13020
# 2            8.5186        13.66200
# 3            7.0032        11.85400
# 4            5.8598         6.82330
# ..              ...             ...
# 92           5.8707         7.20290
# 93           5.3054         1.98690
# 94           8.2934         0.14454
# 95          13.3940         9.05510
# 96           5.4369         0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# **Modifying the columns name for uniformaty**

# %%
df = df.rename(columns={i:i.lower().replace(' ','_') for i in df.columns})
df
# Out:
#     city_population  average_profit
# 0            6.1101        17.59200
# 1            5.5277         9.13020
# 2            8.5186        13.66200
# 3            7.0032        11.85400
# 4            5.8598         6.82330
# ..              ...             ...
# 92           5.8707         7.20290
# 93           5.3054         1.98690
# 94           8.2934         0.14454
# 95          13.3940         9.05510
# 96           5.4369         0.61705
#
# [97 rows x 2 columns]
