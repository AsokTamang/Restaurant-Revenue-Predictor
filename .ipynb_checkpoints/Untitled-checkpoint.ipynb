# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import pandas as pd
import math

# %% [markdown]
# **Reading the data**

# %%
df = pd.read_csv('data/first_data.txt',header=None,names=['City Population','Restaurant_Profit'])
df
# Out:
#     City Population  Restaurant_Profit
# 0            6.1101           17.59200
# 1            5.5277            9.13020
# 2            8.5186           13.66200
# 3            7.0032           11.85400
# 4            5.8598            6.82330
# ..              ...                ...
# 92           5.8707            7.20290
# 93           5.3054            1.98690
# 94           8.2934            0.14454
# 95          13.3940            9.05510
# 96           5.4369            0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# **Modifying the columns name for uniformaty**

# %%
df = df.rename(columns={i:i.lower().replace(' ','_') for i in df.columns})
df
# Out:
#     city_population  restaurant_profit
# 0            6.1101           17.59200
# 1            5.5277            9.13020
# 2            8.5186           13.66200
# 3            7.0032           11.85400
# 4            5.8598            6.82330
# ..              ...                ...
# 92           5.8707            7.20290
# 93           5.3054            1.98690
# 94           8.2934            0.14454
# 95          13.3940            9.05510
# 96           5.4369            0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# **Column city_population represent the population of city, whose actual value is the value times 10,000 and the column average_profit represent the profit of restaurant in each city in the units of $10,000**

# %% [markdown]
# **Studying the data**

# %%
X_train = np.array(df['city_population'])
m=X_train.shape[0]
print(f'The number of training examples is {m}')
Y_train = np.array(df['restaurant_profit'])
print(f'The profit of a restaurant in each city is {Y_train}')
# Out:
# The number of training examples is 97
# The profit of a restaurant in each city is [17.592    9.1302  13.662   11.854    6.8233  11.886    4.3483  12.
#   6.5987   3.8166   3.2522  15.505    3.1551   7.2258   0.71618  3.5129
#   5.3048   0.56077  3.6518   5.3893   3.1386  21.767    4.263    5.1875
#   3.0825  22.638   13.501    7.0467  14.692   24.147   -1.22     5.9966
#  12.134    1.8495   6.5426   4.5623   4.1164   3.3928  10.117    5.4974
#   0.55657  3.9115   5.3854   2.4406   6.7318   1.0463   5.1337   1.844
#   8.0043   1.0179   6.7504   1.8396   4.2885   4.9981   1.4233  -1.4211
#   2.4756   4.6042   3.9624   5.4141   5.1694  -0.74279 17.929   12.054
#  17.054    4.8852   5.7442   7.7754   1.0173  20.992    6.6799   4.0259
#   1.2784   3.3411  -2.6807   0.29678  3.8845   5.7014   6.7526   2.0576
#   0.47953  0.20421  0.67861  7.5435   5.3436   4.2415   6.7981   0.92695
#   0.152    2.8214   1.8451   4.2959   7.2029   1.9869   0.14454  9.0551
#   0.61705]

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_train,Y_train,marker='x',c='b')
plt.title('Profit vs Population per city')
plt.xlabel('Population of city in 10,000d')
plt.ylabel('Profit of restaurant in $10,000')
plt.show()

# %% [markdown]
# **Cost Function**

# %%
def cost_function(w,x,b,y):
    m= x.shape[0]
    total_cost = 0
    for i in range(m):
        y_pred = np.dot(x[i],w) + b
        error = y_pred - y[i]
        sqaured_error = np.square(error)
        total_cost+=sqaured_error
    return total_cost / (2*m)    
w_init = 2
b_init = 1
cost = cost_function(w_init,X_train,b_init,Y_train)
print(f'The initial cost is: {cost:.3f}')
# Out:
# The initial cost is: 75.203

# %% [markdown]
# **Computing the partial derivative**

# %%
def gradient(w,x,b,y):
    m = x.shape[0]  #number of training examples
    dj_dw = 0  #partial derivative with respect to weight
    dj_db = 0  #partial derivative with respect to bias
    for i in range(m):
        y_pred = np.dot(x[i],w) + b
        error = y_pred - y[i]
        dj_db+=error
        dj_dw+= error * x[i]
    return dj_dw/m,dj_db/m
dj_dw,dj_db =  gradient(w_init,X_train,b_init,Y_train)   
print(f'The partial derivatives are: {dj_dw,dj_db} derivative of cost function with respect to weight and bias respectively')
# Out:
# The partial derivatives are: (np.float64(105.63883589856707), np.float64(11.480464948453616)) derivative of cost function with respect to weight and bias respectively

# %% [markdown]
# **Training the model using gradient descent**

# %%
def gradient_descent(w_init,x,b_init,y,gradient,cost_function,alpha,iterations):
    m = x.shape[0]
    w = copy.deepcopy(w_init)
    b = b_init
    cost_history = []
    iterations_history = []
    for i in range(iterations):
        cost = cost_function(w,x,b,y)
        dj_dw,dj_db = gradient(w,x,b,y)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
        if i % math.ceil(iterations/10) ==0:
            cost_history.append(cost)
            iterations_history.append(i)
    return w,b,cost_history, iterations_history
initial_w = 0.
initial_b = 0.
# some gradient descent settings
iterations = 1500
alpha = 0.01    
final_w,final_b,cost_history, iterations_history = gradient_descent(initial_w,X_train,initial_b,Y_train,gradient,cost_function,alpha,iterations)        
print(f'The parameters of the model are weight:{final_w} and bias:{final_b} respectively')
# Out:
# The parameters of the model are weight:1.166362350335582 and bias:-3.63029143940436 respectively

# %% [markdown]
# **plotting the learning curve**

# %%
plt.plot(iterations_history,cost_history)
plt.xlabel('Number of iterations')
plt.ylabel('Loss Function')
plt.show()

# %% [markdown]
# **As we can observe from the learning curve that the loss function is decreasing overtime and is converging after about 700 iterations approximately**

# %% [markdown]
# **Plotting prediction done by our model and the target datas**

# %%
plt.scatter(X_train,Y_train,label='Target Datas',marker='x',c='b')
plt.plot(X_train,np.dot(X_train,final_w) + final_b,label='Linear Regression model',c='r')
plt.xlabel("City's Population in 10,000")
plt.ylabel("Restaurant Profit in $10,000")
plt.show()

# %% [markdown]
# **The visualization indicates that the model predictions closely align with the actual target values, suggesting a good fit.**
